# %% [markdown]
# # Text Classification
#
# In class, we spent some time on text classification, including naive Bayes classifiers.  We focused on these models not only because they are simple to implement and fairly effective, but also because of their similarity to widely used bag-of-words retrieval models such as BM25 and query likelihood.
#
# Your task is to write a naive Bayes text categorization system to predict whether movie reviews are positive or negative.  The data for this **sentiment analysis** task were first assembled and published in Bo Pang and Lillian Lee, &ldquo;A Sentimental Education: Sentiment Analysis Using Subjectivity Summarization Based on Minimum Cuts&rdquo;, _Proceedings of the Association for Computational Linguistics_, 2004.
#
# ## Loading the data
#
# First we load the training, development, and test splits of this dataset.

# %%
import json
from urllib.request import urlopen
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read one JSON record per line

def read_jsonl(f):
  res = []
  for line in f:
    res.append(json.loads(line))
  return res

# %% [markdown]
# If you're working offline, you could modify this code to read from the copies of the data in the repository.

# %%
train = read_jsonl(urlopen("https://github.com/dasmiq/cs6200-hw3/blob/main/train.json?raw=true"))
dev = read_jsonl(urlopen("https://github.com/dasmiq/cs6200-hw3/blob/main/dev.json?raw=true"))
test = read_jsonl(urlopen("https://github.com/dasmiq/cs6200-hw3/blob/main/test.json?raw=true"))

# %% [markdown]
# Each of these subsets of the data is a list of documents, and each document has a unique identifier (`id`) and text (`text`). The training and development documents, in addition, have been labeled with a `class`.

# %%
print(train[0])
print(dev[0])
print(test[0])
# Out:
# {'id': '12178', 'class': 'neg', 'text': "the sequel to the fugitive ( 1993 ) , u . s marshals is an average thriller using it's association with the fugitive just so it can make a few extra bucks . \ntommy lee jones returns to his role as chief deputy samuel gerard , the grizzly cop who was after harrison ford in the fugitive . \nthis time , he's after fugitive mark sheridan ( snipes ) who the police think killed two fbi agents , but of course he's been set up , and when the police plane escort he ( and gerard ) are riding crashes , he makes a run for it , gerard not so hot on his tail . \nwhat follows is about 2 hours of action , brought to us by the director of executive decision ( 1995 ) , another film curiously involving a plane . \nwhen comparing this movie to the fugitive , the prequel is far superior . \nbut even on it's own , u . s marshals is a pretty lousy movie . \nwhile the original was reasonably intelligent , and had a fugitive to root for , the audience feels strangely distanced from snipes fugitive , mainly because we know so little about him until way into the film's overlong running time . \nwhile the fugitive gave a little time to develop harrison fords character , u . s marshals is straight in there , pulling it's trump card ( the place crash ) almost immediately . \nto be honest , i couldn't care less if snipe's character got captured or not . \nsnipes performance is average , and his character gets surprisingly little screen time ( considering he is the fugitive ) for reasons i'll explain later . \ntommy lee jones is as fine as ever , although his role is hardly a challenge . \nthe sense of deja vu was overwhelming . \ni know it's the same role from the fugitive , but there is seemingly no attempt to develop his character from the last film . \nthere's a few 'nudge nudge' references from the first film , but apart from that , nothing . \nnobody even mentions harrison ford in this movie . \ndowney jnr is ok as fbi agent john royce who's roped into the chase , and sexy french actress irene jacob wanders in and out of the movie as snipes wife . \nnobody looks as if their having a good time , and all the performers are on autopilot . \nthe supporting cast are o . k , but when it comes to performances , u . s marshals falls flat on it's face . \nit doesn't fare any better plot-wise , either . \nthe film starts off with gerard trying to capture snipes , but then veers off into terrorists territory . \nas said above , the film is an normal , average terrorist thriller , seen a million times before , but is using the f
#
# The text has been pre-tokenized and lower-cased.  All you have to do to get the individual terms in a review is to split the tokens by whitespace, a sequence of spaces and/or newlines.

# %%
## TODO: Write a function to convert a document into a collection of terms and their counts.
## Convert the lists of documents in the training, development, and test sets into these collections of terms and counts.

#collection of terms and counts of the dev set 

import operator
sorted_d_train = {}
d = {}
def train_set():
  for j in train:
    a = j['text'].split(' ')
    for i in a:
      if i not in d:
        d[i] = 1
      else:
        d[i] += 1
  sorted_d_train = sorted(d.items(), key=operator.itemgetter(1))
  sorted_d_train = dict( sorted(d.items(), key=operator.itemgetter(1),reverse=True))
  print(sorted_d_train)

train_set()
# Out:
# {',': 61975, 'the': 54652, '.': 52836, 'a': 29715, 'and': 26874, 'of': 26854, 'to': 25058, 'is': 19891, 'in': 15980, '"': 14400, 'that': 11743, ')': 9451, '(': 9350, 'it': 8482, 'as': 8343, 'with': 8299, 'for': 7518, 'his': 7268, 'film': 7103, 'this': 6403, '\nthe': 6216, 'on': 5542, 'are': 5498, 'but': 5431, 'he': 4942, 'by': 4848, 'be': 4834, 'i': 4475, 'an': 4472, 'movie': 4266, 'who': 4245, 'not': 4138, 'one': 4002, 'was': 3944, 'have': 3896, 'has': 3825, 'from': 3803, 'at': 3673, 'her': 3374, 'you': 3318, 'all': 3144, '?': 3050, '\n': 3048, 'they': 2878, 'about': 2781, 'out': 2735, 'like': 2717, 'more': 2591, 'so': 2509, ':': 2492, 'which': 2451, 'up': 2450, 'their': 2345, 'or': 2332, 'some': 2245, 'just': 2175, 'into': 2102, 'him': 2099, 'what': 2085, 'when': 2042, "it's": 1978, 'than': 1937, 'only': 1889, 'good': 1837, 'time': 1809, 'its': 1764, 'can': 1759, 'no': 1734, 'even': 1727, 'story': 1702, 'most': 1702, 'she': 1691, 'will': 1689, 'if': 1662, 'been': 1653, 'would': 1625, 'much': 1557, '\ni': 1530, 'we': 1526, 'get': 1525, 'there': 1493, 'character': 1475, 'do': 1475, 'other': 1472, 'them': 1471, 'very': 1468, '\nbut': 1460, ';': 1446, 'characters': 1416, '\nit': 1408, 'two': 1404, 'also': 1403, '!': 1381, 'see': 1371, 'way': 1347, 'first': 1339, '\nand': 1318, '\nin': 1266, 'because': 1259, '\nthis': 1250, 'really': 1250, 'does': 1238, 'make': 1237, 'had': 1220, 'any': 1208, 'films': 1197, 'too': 1197, 'little': 1189, 'life': 1150, 'plot': 1141, 'me': 1132, '\nhe': 1125, 'well': 1121, 'where': 1120, 'off': 1111, 'could': 1102, 'bad': 1091, 'people': 1091, 'scene': 1087, 'after': 1060, 'how': 1060, 'best': 1058, '-': 1037, "\nit's": 1030, 'over': 1017, 'never': 1017, 'being': 1009, "doesn't": 997, 'my': 996, 'new': 995, 'man': 988, 'scenes': 977, 'know': 976, 'were': 954, 'then': 942, 'such': 937, '--': 935, 'many': 925, 'through': 922, 'movies': 893, 'while': 891, 'these': 891, "don't": 889, 'great': 886, 'action': 865, '*': 857, 'us': 845, 'end': 844, 'love': 844, 'go': 837, 'seems': 825, 'back': 825, 'something': 820, 'work': 820, 'made': 802, 'here': 796, 'another': 788, 'makes': 780, 'world': 780, 'those': 770, 'big': 764, "he's": 747, 'few': 745, 'still': 744, 'between': 739, '\nas': 732, 'better': 729, 'enough': 729, 'before': 726, 'director': 715, 'seen': 715, 'performance': 707, 'around': 706, 'audience': 698, 'real': 697, 'down': 697, 'may': 695, 'every': 694, 'role': 692, 'going': 691, 'gets': 690, 'should': 688, 'your': 686, 'think': 683, '\nthere': 678, 'though': 675, 'years': 671, 'same': 669, 'take': 662, '\na': 657, "isn't": 656, 'own': 651, 'both': 647, 'things': 646, 'thing': 642, 'actually': 639, 'look': 630, 'comedy': 629, 'last': 628, 'script': 628, 'say': 627, 'almost': 626, 'funny': 625, 'find': 623, 'fact': 621, 'played': 615, 'plays': 610, 'right': 603, 'cast': 602, 'old': 600, 'nothing': 597, 'long': 596, 'did': 594, 'come': 591, 'ever': 590, '\nif': 590, 'show': 571, 'young': 570, 'comes': 569, '\nwhen': 564, 'now': 560, 'least': 557, 'why': 551, 'part': 545, 'john': 543, 'lot': 542, 'actors': 533, '\nthey': 533, 'since': 532, 'acting': 532, 'himself': 530, 'point': 528, 'without': 526, 'away': 524, 'takes': 523, 'course': 522, 'original': 519, 'each': 519, 'goes': 518, 'again': 511, 'family': 508, 'must': 504, 'star': 504, 'interesting': 500, 'minutes': 499, 'quite': 498, 'might': 498, 'screen': 493, 'guy': 492, 'effects': 491, 'anything': 489, "there's": 486, 'day': 486, 'place': 485, "can't": 485, 'far': 478, 'year': 477, 'three': 474, "that's": 474, 'rather': 470, "film's": 468, 'seem': 460, "didn't": 459, 'our': 455, 'fun': 453, 'home': 452, 'kind': 447, 'times': 446, 'during': 445, 'picture': 445, 'trying': 444, 'watch': 442, 'always': 442, 'sense': 441, 'wife': 441, 'job': 441, 'want': 441, '\nhis': 441, 'special': 438, 'making': 436, 'series': 435, 'bit': 433, 'pretty': 432, 'give': 432, 'help': 428, 'becomes': 427, 'american': 421, 'woman': 419, 'men': 413, 'become': 412, '\nho ...

# %%
#collection of terms and counts of the test set 

sorted_d_test = {}
d = {}
def test_set():
  for j in test:
    a = j['text'].split(' ')
    for i in a:
      if i not in d:
        d[i] = 1
      else:
        d[i] += 1
  sorted_d_test = sorted(d.items(), key=operator.itemgetter(1))
  sorted_d_test = dict( sorted(d.items(), key=operator.itemgetter(1),reverse=True))
  print(sorted_d_test)
test_set()
# Out:
# {',': 8011, 'the': 7049, '.': 6773, 'a': 3721, 'and': 3561, 'of': 3518, 'to': 3222, 'is': 2652, 'in': 2020, '"': 1814, 'that': 1532, ')': 1204, '(': 1197, 'with': 1096, 'it': 1069, 'as': 1056, 'for': 986, 'his': 895, 'film': 874, '\nthe': 856, 'this': 812, 'on': 734, 'are': 709, 'but': 709, 'he': 637, 'an': 624, 'movie': 611, 'be': 611, 'by': 593, 'i': 573, 'not': 565, 'one': 528, 'from': 517, 'was': 514, 'her': 513, 'who': 505, 'have': 495, 'at': 465, 'has': 448, 'all': 405, 'they': 378, 'about': 375,
ot': 63, 'want': 63, 'again': 63, 'did': 63, 'least': 63, 'goes': 62, 'himself': 62, 'always': 62, 'away': 62, 'comedy': 62, 'looking': 62, 'trying': 61, 'show': 61, 'fun': 61, "that's": 61, 'yet': 60, 'help': 60, 'since': 60, 'anything': 60, 'three': 59, 'making': 59, 'our': 59, 'sure': 58, 'special': 57, 'gives': 56, 'job': 56, 'each': 56, 'give': 56, 'rather': 56, 'wife': 55, 'although': 54, 'ending': 53, 'actor': 53, "film's": 53, 'might': 53, 'without': 53, 'series': 52, "didn't": 52, 'done': 52, 'everything': 52, 'sex': 52, 'music': 52, 'black': 52, 'seem': 51, 'written': 51, 'kind': 51, 'high': 51, 'itself': 50, 'completely': 50, 'turns': 49, 'horror': 49, '\nthey': 49, 'wars': 49, 'looks': 49, 'reason': 48, 'watching': 48, 'whole': 48, 'family':  ...

# %%
#collection of terms and counts of the dev set 

sorted_d_dev = {}
d = {}
def dev_set():
  for j in dev:
    a = j['text'].split(' ')
    for i in a:
      if i not in d:
        d[i] = 1
      else:
        d[i] += 1
  sorted_d_dev = sorted(d.items(), key=operator.itemgetter(1))
  sorted_d_dev = dict( sorted(d.items(), key=operator.itemgetter(1),reverse=True))
  print(sorted_d_dev)
dev_set()
# Out:
# {',': 7731, 'the': 6667, '.': 6267, 'a': 3687, 'of': 3326, 'and': 3291, 'to': 3191, 'is': 2474, 'in': 2012, 'that': 1493, '"': 1398, ')': 1126, '(': 1117, 'as': 1023, 'with': 1012, 'it': 995, 'for': 923, 'film': 866, 'his': 845, 'this': 750, '\nthe': 738, 'on': 703, 'are': 700, 'but': 658, 'he': 612, 'be': 607, 'by': 598, 'who': 556, 'movie': 542, 'i': 541, 'an': 523, 'one': 506, 'from': 501, 'not': 493, 'have': 480, 'at': 454, 'was': 445, 'her': 434, 'has': 433, 'all': 417, 'they': 372, 'you': 360, '\n': 349, '?': 347, 'about': 345, 'which': 345, 'more': 343, 'like': 336, 'or': 324, 'so': 323, 'out': 321, 'their': 321, 'up': 317, 'just': 296, 'when': 294, 'him': 276, 'she': 265, 'some': 255, ':': 252, 'into': 250, 'than': 248, 'only': 246, 'what': 242, ';': 229, "it's": 225, 'its': 223, 'time': 222, 'no': 218, 'character': 217, 'can': 216, 'will': 215, 'good': 214, 'even': 213, 'much': 207, 'would': 201, 'there': 201, 'most': 200, 'them': 200, 'story': 194, 'been': 193, 'very': 193, 'if': 193, 'characters': 190, 'other': 185, '\nit': 183, 'do': 180, 'two': 180, '\nbut': 178, 'we': 176, 'make': 169, 'being': 168, 'get': 167, 'any': 165, '\ni': 164, 'way': 163, 'also': 161, 'because': 160, '\nthis': 160, '\nand': 159, '-': 159, '!': 159, 'first': 157, 'where': 156, 'too': 156, 'life': 156, 'how': 155, 'never': 153, 'had': 152, '\nin': 152, 'scene': 151, 'after': 151, 'off': 150, 'people': 147, 'see': 140, 'bad': 139, 'my': 138, 'scenes': 137, '\nhe': 137, 'new': 136, 'well': 134, 'does': 134, 'could': 133, 'really': 133, 'me': 133, 'man': 131, 'many': 131, 'such': 130, 'films': 129, 'were': 127, 'through': 124, 'love': 124, '*': 123, 'us': 121, 'little': 120, 'plot': 119, "doesn't": 116, 'over': 115, "\nit's": 115, 'these': 114, 'great': 113, 'while': 112, 'before': 112, 'few': 112, 'movies': 111, 'know': 109, 'best': 107, 'something': 105, "isn't": 103, "don't": 103, 'fact': 102, 'made': 102, 'between': 102, 'seems': 102, 'funny': 101, 'comedy': 101, 'makes': 100, 'played': 100, '--': 100, 'action': 98, 'end': 97, 'take': 95, 'those': 93, 'around': 93, 'director': 91, 'role': 91, 'come': 90, 'still': 90, 'go': 89, 'though': 88, 'then': 88, 'performance': 88, 'same': 88, 'look': 88, 'here': 87, 'why': 86, 'gets': 86, '\nthere': 85, 'say': 84, 'comes': 84, 'last': 83, 'another': 83, 'own': 82, 'going': 82, 'seen': 81, 'takes': 81, 'every': 80, "he's": 80, 'should': 80, 'actually': 80, 'audience': 79, '\na': 79, 'work': 79, 'may': 78, 'world': 78, 'back': 78, '\nas': 77, 'down': 77, 'right': 77, 'long': 76, 'both': 76, 'enough': 75, 'real': 75, 'things': 75, 'original': 75, 'actors': 74, 'place': 74, 'better': 74, 'think': 74, "can't": 73, 'big': 73, 'years': 73, 'might': 72, 'again': 72, 'did': 71, 'city': 71, 'without': 71, 'plays': 70, 'young': 69, 'sense': 69, 'nothing': 69, 'thing': 69, 'lot': 69, 'times': 69, 'three': 69, 'quite': 68, 'find': 68, 'now': 68, '\nif': 67, 'ever': 66, '\nthey': 66, 'part': 66, 'show': 66, 'bit': 66, 'your': 65, 'since': 65, 'almost': 65, 'himself': 64, 'away': 64, 'john': 64, 'seem': 63, 'minutes': 62, 'watch': 62, 'rather': 62, 'goes': 62, 'always': 61, 'screen': 61, 'effects': 61, 'each': 60, 'give': 60, 'during': 60, 'point': 60, 'interesting': 60, 'family': 60, 'must': 59, 'acting': 59, 'anything': 59, 'friends': 59, 'cast': 59, 'making': 58, 'wants': 58, 'guy': 58, "film's": 57, 'moments': 57, 'hard': 57, 'picture': 57, 'dialogue': 57, 'especially': 57, '\nwhen': 57, 'entire': 57, 'special': 56, 'play': 56, 'set': 56, 'trying': 56, "there's": 55, 'got': 55, 'become': 55, 'everything': 55, 'gives': 55, "didn't": 54, 'house': 54, 'least': 54, 'old': 54, 'evil': 54, '\nshe': 54, 'horror': 54, 'yet': 53, 'completely': 53, 'far': 53, 'becomes': 53, 'high': 53, 'job': 53, 'night': 52, 'hollywood': 52, 'wife': 51, 'next': 51, 'want': 51, 'simply': 51, 'fun': 51, '\nso': 51, 'script': 51, '\none': 51, 'star': 51, 'home': 50, 'given': 50, 'begins': 49, 'kind': 49, 'death': 49, 'course': 49, 'name': ...

# %% [markdown]
# The statistics for individual documents will be useful in predicting the class of those documents, e.g., in the test set.
#
# Now, you will collect the statistics used to estimate the parameters of a naive Bayes model.

# %%
## TODO: Write a function to take a list of document statistics and produce a dictionary of term counts in each class.
## Your output will look something like this:

fakeData = {'pos': {'the': 10000, 'and': 800},
            'neg': {'the': 1001, 'and': 799}}
fakeData = {}
posdict = {}
negdict = {}
d = {}

def fake():
  for j in train:
    if j['class'] == 'pos':
      a = j['text'].split(' ')
      for k in a:
        if k not in posdict:
          posdict[k] = 1
        else:
          posdict[k] += 1
    else:
      a = j['text'].split(' ')
      for k in a:
        if k not in negdict:
          negdict[k] = 1
        else:
          negdict[k] += 1 
  sorted_pos_d = sorted(posdict.items(), key=operator.itemgetter(1))
  sorted_pos_d = dict( sorted(posdict.items(), key=operator.itemgetter(1),reverse=True))
  fakeData['pos'] = sorted_pos_d
  sorted_neg_d = sorted(negdict.items(), key=operator.itemgetter(1))
  sorted_neg_d = dict( sorted(negdict.items(), key=operator.itemgetter(1),reverse=True))
  fakeData['neg'] = sorted_neg_d
  print(fakeData)
fake()
# Out:
# {'pos': {',': 33785, 'the': 29579, '.': 26984, 'a': 15793, 'and': 15101, 'of': 14671, 'to': 12943, 'is': 11072, 'in': 8508, '"': 6944, 'that': 6089, ')': 4841, '(': 4816, 'as': 4754, 'with': 4567, 'it': 4424, 'his': 4239, 'for': 3977, 'film': 3879, '\nthe': 3333, 'this': 3041, 'are': 2944, 'he': 2823, 'but': 2813, 'on': 2785, 'by': 2723, 'be': 2356, 'an': 2352, 'who': 2312, 'not': 2200, 'i': 2135, 'one': 2102, 'has': 2074, 'from': 2039, 'was': 1984, 'movie': 1877, 'at': 1862, 'have': 1776, 'her': 1768, 'you': 1668, 'all': 1573, '\n': 1489, 'they': 1468, 'more': 1409, 'which': 1358, 'about': 1355, 'out': 1344, '?': 1309, 'like': 1301, 'their': 1260, 'up': 1230, ':': 1219, 'so': 1194, 'him': 1182, 'or': 1119, 'into': 1106, 'some': 1098, 'what': 1083, 'most': 1047, 'when': 1042, "it's": 1036, 'than': 1010, 'just': 1006, 'will': 986, 'story': 978, 'its': 975, 'time': 932, 'good': 928, 'can': 909, 'very': 907, 'only': 874, 'she': 870, 'also': 866, 'other': 823, 'we': 819, 'would': 798, 'even': 787, 'much': 778, 'been': 777, 'character': 771, ';': 771, 'life': 768, '\nbut': 768, 'see': 765, 'them': 762, 'if': 760, 'characters': 746, '\nit': 745, 'two': 745, 'no': 741, 'way': 737, 'first': 734, 'get': 699, 'well': 692, 'there': 688, '\nin': 681, 'does': 680, 'films': 672, 'do': 672, 'best': 661, 'because': 659, '\nthis': 657, '\nhe': 651, '\ni': 643, 'really': 625, '\nand': 617, 'little': 611, '-': 602, 'make': 601, 'great': 592, 'people': 592, 'too': 588, 'where': 582, 'had': 578, 'many': 566, 'new': 565, 'man': 561, 'scene': 556, 'being': 554, 'after': 548, 'over': 538, 'never': 536, 'me': 534, 'any': 529, 'how': 528, 'world': 516, "\nit's": 507, 'off': 506, 'love': 499, 'while': 498, '!': 495, 'such': 493, 'could': 489, '--': 486, 'scenes': 485, 'these': 485, 'were': 478, 'movies': 477, 'through': 475, "doesn't": 467, 'us': 463, 'my': 462, 'plot': 453, 'know': 451, 'back': 440, 'makes': 440, 'performance': 439, 'seen': 438, 'end': 431, 'then': 430, '\nas': 427, 'between': 427, 'work': 426, 'go': 424, 'seems': 419, 'both': 418, 'those': 418, 'own': 413, 'may': 409, 'still': 407, 'something': 404, 'another': 393, "don't": 391, 'role': 390, 'action': 389, 'years': 388, 'though': 377, 'here': 375, 'few': 374, 'made': 372, 'real': 366, 'same': 364, 'before': 363, "he's": 361, 'take': 353, 'down': 352, 'big': 352, 'your': 352, 'young': 344, 'almost': 344, 'enough': 343, 'right': 343, 'family': 341, 'find': 340, 'every': 338, 'audience': 337, 'around': 335, '\nthere': 334, '\na': 331, 'gets': 330, 'last': 327, 'things': 326, '*': 323, 'director': 322, 'come': 322, 'quite': 322, 'ever': 321, 'think': 321, 'going': 319, 'fact': 318, 'cast': 317, 'old': 314, 'say': 313, 'long': 311, 'played': 311, 'each': 311, 'actually': 309, 'look': 305, 'plays': 304, 'funny': 304, 'takes': 303, 'comedy': 303, 'better': 302, 'now': 300, 'without': 299, 'thing': 297, 'comes': 297, '\nwhen': 296, 'show': 295, 'himself': 292, 'bad': 292, 'john': 291, 'star': 283, "isn't": 282, 'american': 281, 'always': 279, 'lot': 278, 'should': 276, 'part': 275, 'away': 273, 'year': 272, 'since': 268, 'job': 267, 'place': 266, 'again': 261, 'rather': 261, 'did': 261, 'picture': 260, 'screen': 260, 'day': 258, 'must': 258, '\nhis': 258, 'actors': 258, '\nhowever': 258, 'sense': 257, "film's": 256, 'course': 256, 'original': 254, 'fun': 254, 'times': 253, 'home': 253, 'our': 251, 'men': 249, 'gives': 249, 'bit': 247, 'wife': 246, 'making': 246, 'become': 246, 'goes': 245, 'during': 244, 'script': 244, '\nif': 244, '\nthey': 243, 'yet': 243, 'effects': 243, 'acting': 243, 'although': 241, 'three': 241, 'far': 240, 'help': 239, 'seem': 237, 'anything': 236, 'nothing': 235, 'watch': 235, 'interesting': 234, 'might': 233, 'together': 232, 'kind': 228, 'point': 228, 'different': 228, 'special': 227, 'black': 224, 'set': 222, '\none': 222, 'performances': 220, 'least': 220, 'becomes': 220, 'father': 219, 'why': 219, "that's": 219, 'hollywood': 217, 'feel': 214, 'especially': 213,  ...

# %% [markdown]
# ## Estimating naive Bayes parameters
#
# As we discussed in class, you could use simple maximum-likelihood estimation for naive Bayes parameters, i.e., computing the relative frequency of a term given a class. The problem is that the relative frequency of words not seen in the training data will be zero, e.g., $p(\texttt{aardvark} | \texttt{pos}) = \frac{0}{\textrm{tokens in the positive training data}}$.
#
# To avoid this problem, estimate the parameters with **add-1 (Laplace) smoothing**. In other words, add an additional count of 1 to each word type. Then, to make the probability distribution sum to 1, add a count of 1 for each vocabulary word to the denominator. For our `aardvark` example, we would now have, for vocabulary $V$, $p(\texttt{aardvark} | \texttt{pos}) = \frac{0 + 1}{N_{\texttt{pos}} + 1 \cdot |V|}$

# %%
## TODO: Write a function to compute the add-1 smoothed parameters for a naive Bayes model given the term statistics you computed above.
## Collect these parameters for the training set.

def smoothed_param(word, sorted_dict,N_pos,V):
  return (sorted_dict[word] + 1) / (N_pos + V)
#For positive class
N_pos = sum(sorted_pos_d.values())
V = len(sorted_d_train)
sorted_pos_d_smoothed = {}
for word in sorted_pos_d:
  sorted_pos_d_smoothed[word] = smoothed_param(word,sorted_pos_d,N_pos,V)
#For negative class
N_neg = sum(sorted_neg_d.values())
sorted_neg_d_smoothed = {}
for word in sorted_neg_d:
  sorted_neg_d_smoothed[word] = smoothed_param(word,sorted_neg_d,N_neg,V)

# %% [markdown]
# What terms are likely to be important for prediction?

# %%
## TODO: Print a list of the 25 terms with the highest log ratio of positive to negative weight.

import numpy as np
l = {}
for i in sorted_pos_d:
  if i in sorted_neg_d:
    # if np.log(sorted_neg_d[i]) == 0:
    #   print(i)
      logratio = np.log(sorted_pos_d[i]/sorted_neg_d[i])
      l[i] = logratio
sort_orders = sorted(l.items(), key=lambda x: x[1], reverse=True)
print(sort_orders[:26])
# Out:
# [('mulan', 4.127134385045092), ('flynt', 4.060443010546419), ('lebowski', 3.6888794541139363), ('religion', 3.4657359027997265), ('jude', 3.295836866004329), ('anna', 3.295836866004329), ('crowe', 3.258096538021482), ('obi-wan', 3.1780538303479458), ('margaret', 3.091042453358316), ('frequency', 3.044522437723423), ('cauldron', 3.0204248861443626), ('winslet', 2.995732273553991), ('nello', 2.995732273553991), ('vulnerable', 2.9444389791664403), ('hatred', 2.8903717578961645), ('kenobi', 2.8903717578961645), ('outstanding', 2.833213344056216), ('avoids', 2.833213344056216), ('siege', 2.833213344056216), ('fascination', 2.833213344056216), ('pleasantville', 2.833213344056216), ('darker', 2.833213344056216), ('africans', 2.833213344056216), ('damon', 2.8134107167600364), ('astounding', 2.772588722239781), ('mamet', 2.772588722239781)]

# %%
## TODO: Print a list of the 25 terms with the highest log ration of negative to positive weight.
import numpy as np
l = {}

for i in sorted_pos_d:
  if i in sorted_neg_d:
      logratio = np.log(sorted_neg_d[i]/sorted_pos_d[i])
      l[i] = logratio
sort_orders = sorted(l.items(), key=lambda x: x[1], reverse=True)
print(sort_orders[:26])
# Out:
# [('8mm', 3.6109179126442243), ('werewolf', 3.2188758248682006), ('hudson', 3.091042453358316), ('chuckle', 3.044522437723423), ('insulting', 3.044522437723423), ('jawbreaker', 2.995732273553991), ("charlie's", 2.995732273553991), ('schumacher', 2.970414465569701), ('dalmatians', 2.9444389791664403), ('uninvolving', 2.8903717578961645), ('jakob', 2.833213344056216), ('\nyeah', 2.772588722239781), ('ludicrous', 2.740840023925201), ('illogical', 2.70805020110221), ('buster', 2.6390573296152584), ('idiotic', 2.6026896854443837), ('jeopardy', 2.5649493574615367), ('macleane', 2.5649493574615367), ('wrestling', 2.505525936990736), ('nonsense', 2.4849066497880004), ('magoo', 2.4849066497880004), ('darryl', 2.4849066497880004), ('julian', 2.4849066497880004), ('claw', 2.4849066497880004), ('compensate', 2.4849066497880004), ('coma', 2.4849066497880004)]

# %% [markdown]
# Now, given the parameters you've estimated, you can make predictions about new documents.

# %%
## TODO: Compute the predictions of your model for each document in the development data.

devPredictions = []
r = 0 
j = 0 
for i in train:
  j += 1
  if i['class'] == 'pos':
    r += 1 
prob_pos = r/j
for j in range(len(dev)):
  ans1 = 0
  for i in dev[j]['text'].split(' '):
    i = i.strip()
    if i in sorted_pos_d:
      d = np.log(sorted_pos_d_smoothed[i])
    else:
      d = np.log((0 + 1) / (N_pos + V))
    ans1 = ans1 + d
  ans2 = 0
  for i in dev[j]['text'].split(' '):
    i = i.strip()
    if i in sorted_neg_d:
      d = np.log(sorted_neg_d_smoothed[i])
    else:
      d = np.log((0 + 1) / (N_neg + V))
    ans2 = ans2 + d
  if ans1 > ans2:
    devPredictions.append('pos')
  else:
    devPredictions.append('neg')
print(devPredictions)
# Out:
# ['pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'pos', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'pos', 'pos', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'pos', 'pos', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg']

# %%
## TODO: Write a function to compute the accuracy of predictions given correct classes.

devClasses = [x['class'] for x in dev]
def accuracy(predictions, devClasses):
  a = 0 
  b = 0 
  for i in range(len(predictions)): 
      if predictions[i] == devClasses[i]:
        a += 1 
  return a/len(predictions)
accuracy(devPredictions, devClasses)
# Out:
# 0.77

# %%
## TODO: Compute the predictions of this model on each document in the test set.

testPredictions = []
r = 0 
j = 0 
for i in train:
  j += 1
  if i['class'] == 'pos':
    r += 1 
prob_pos = r/j
for j in range(len(test)):
  ans1 = 0
  for i in test[j]['text'].split(' '):
    i = i.strip()
    if i in sorted_pos_d:
      d = np.log(sorted_pos_d_smoothed[i])
    else:
      d = np.log((0 + 1) / (N_pos + V))
    ans1 = ans1 + d
  ans2 = 0
  for i in test[j]['text'].split(' '):
    i = i.strip()
    if i in sorted_neg_d:
      d = np.log(sorted_neg_d_smoothed[i])
    else:
      d = np.log((0 + 1) / (N_neg + V))
    ans2 = ans2 + d
  if ans1 > ans2:
    testPredictions.append('pos')
  else:
    testPredictions.append('neg')
print(testPredictions)
# Out:
# ['neg', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'neg', 'pos', 'neg', 'pos', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg']

# %% [markdown]
# ## Comparing models with hypothesis testing (CS6200 only)
#
# Now that you've built a straightforward naive Bayes model, you can try to improve it. You could try stemming words, or including bigrams or trigrams, or adjusting the hyperparameter for Laplace smoothing, or trying a different smoothing method. What you try is up to you.

# %%
## TODO: Try different features and/or smoothing.
## Compute the predictions and the acuracy of your new model on development data.

def smoothed_param(word, sorted_dict,N_pos,V):
  l = 5
  return (sorted_dict[word] + l) / (N_pos + (l*V))
#For positive class
N_pos = sum(sorted_pos_d.values())
V = len(sorted_d_train)
sorted_pos_d_smoothed = {}
for word in sorted_pos_d:
  sorted_pos_d_smoothed[word] = smoothed_param(word,sorted_pos_d,N_pos,V)
#For negative class
N_neg = sum(sorted_neg_d.values())
sorted_neg_d_smoothed = {}
for word in sorted_neg_d:
  sorted_neg_d_smoothed[word] = smoothed_param(word,sorted_neg_d,N_neg,V)

# %%
## TODO: Compute the predictions of your model for each document in the development data.

devPredictions1 = []
r = 0 
j = 0 
for i in train:
  j += 1
  if i['class'] == 'pos':
    r += 1 
prob_pos = r/j
for j in range(len(dev)):
  ans1 = 0
  for i in dev[j]['text'].split(' '):
    i = i.strip()
    if i in sorted_pos_d:
      d = np.log(sorted_pos_d_smoothed[i])
    else:
      d = np.log((0 + 1) / (N_pos + V))
    ans1 = ans1 + d
  ans2 = 0
  for i in dev[j]['text'].split(' '):
    i = i.strip()
    if i in sorted_neg_d:
      d = np.log(sorted_neg_d_smoothed[i])
    else:
      d = np.log((0 + 1) / (N_neg + V))
    ans2 = ans2 + d
  if ans1 > ans2:
    devPredictions1.append('pos')
  else:
    devPredictions1.append('neg')
print(devPredictions1)
# Out:
# ['pos', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'pos', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'neg', 'pos', 'neg', 'neg', 'pos', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'neg', 'pos', 'neg', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos', 'pos', 'pos', 'pos', 'pos']

# %%
## TODO: Write a function to compute the accuracy of predictions given correct classes.

devClasses = [x['class'] for x in dev]
def accuracy1(predictions, devClasses):
  a = 0 
  b = 0 
  for i in range(len(predictions)): 
      if predictions[i] == devClasses[i]:
        a += 1 
  return a/len(predictions)
accuracy1(devPredictions1, devClasses)
# Out:
# 0.785

# %% [markdown]
# Perhaps your new model will be better than your original naive Bayes model above; perhaps it will be worse. (That won't affect your grade.) Your next step is to implement a permutation test to compare the two models. Refer to the material on the bootstrap and permutation tests at the end of the evaluation lecture.

# %%
## TODO: Compute the difference in accuracy between your first naive Bayes model and your new one.

import random
def swap_values_p(list1,list2):
  for i in range(len(list1)):
    num = random.random()
    a = 0 
    if num < 0.5:
      a = list1[i]
      list1[i] = list2[i]
      list2[i] = a
    else:
      continue
  return (list1, list2)
count = 0 
b = 100
for i in range(b):
  l1, l2 = swap_values_p(np.copy(devPredictions), np.copy(devPredictions1))
  acc1 = accuracy(l1, devClasses)
  acc2 = accuracy1(l2, devClasses)
  new = accuracy1(devPredictions1, devClasses)
  old = accuracy(devPredictions, devClasses)
  diff = new - old 
  diff2 = acc2 - acc1
  if diff >= diff2:
    count += 1
pvalue = count/b

# %%
## TODO: Write a function that, given two vectors of predictions that have
## the same length, swaps each pair of predictions with probability 0.5.
## Modify this dummy function that just echoes its inputs.

import random
def permute(list1,list2):
  for i in range(len(list1)):
    num = random.random()
    a = 0 
    if num < 0.5:
      a = list1[i]
      list1[i] = list2[i]
      list2[i] = a
    else:
      continue
  return (list1, list2)

# %%
## TODO: If you run this permute function 500 times on the predictions of your two models,
## it should produce 500 different pairs of vectors.
## Compute the difference in accuracy for each of these 500 pairs, i.e., a vector of 500 differences.

permutationDifferences = []
b = 500
for i in range(b):
  l1, l2 = swap_values_p(np.copy(devPredictions), np.copy(devPredictions1))
  acc1 = accuracy(l1, devClasses)
  acc2 = accuracy1(l2, devClasses)
  new = accuracy1(devPredictions1, devClasses)
  old = accuracy(devPredictions, devClasses)
  diff = new - old 
  diff2 = acc2 - acc1 
  permutationDifferences.append(diff2)

# %%
## TODO: Compute the proportion of these differences that are greater than the actual accuracy difference between your two models.
## This proportion is the p-value computed by this permutation test.

count = 0
for i in range(len(permutationDifferences)):
  if permutationDifferences[i] > diff:
    count += 1
prop = count/b
print(prop)
# Out:
# 0.208

# %%
## This code should plot a histogram of the differences between the permuted vectors
## and the location of the observed accuracy difference.

plt.hist(permutationDifferences, 20, label='Replicates', edgecolor='black')
ylim = plt.ylim()
plt.plot(2 * [difference], ylim, '--g', linewidth=3, label='Observed difference')
plt.ylim(ylim)
plt.legend()
plt.xlabel('Difference in accuracy')
plt.show()
